# %% [markdown]
# <a href="https://colab.research.google.com/github/DeepandraSingh1225/Aws-ML/blob/main/day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# if
num1 = 10
if num1 > 2 :
  print("num1 = ",num1)
print("if end")
# Out:
# num1 =  10
# if end

# %%
# Q1.
age = 18

if age >= 18:
    print("You are eligible to vote.")
# Out:
# You are eligible to vote.

# %%
#Q2.

n1 = int(input("Enter a number: "))
n2 = int(input("Enter a number:"))
n3 = int(input("Enter a number:"))

if n1 > n2 and n1 > n3:
    print("The largest number is:", n1)
elif n2 > n1 and n2 > n3:
    print("The largest number is:", n2)
else:
    print("The largest number is:", n3)
# Out:
# Enter a number: 21
# Enter a number:22
# Enter a number:23
# The largest number is: 23

# %%
# Q3
number = 7

if number % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Odd

# %%
# Q3

marks = 75

if marks >= 90:
    print("Grade A")
elif marks >= 70:
    print("Grade B")
elif marks >= 50:
    print("Grade C")
else:
    print("Fail")
# Out:
# Grade B

# %%
# Q4

age = 20
has_id = True

if age >= 18 and has_id:
    print("Entry allowed")
else:
    print("Entry denied")
# Out:
# Entry allowed

# %%
# Q5

day = "Sunday"

if day == "Saturday" or day == "Sunday":
    print("Weekend")
else:
    print("Weekday")
# Out:
# Weekend

# %%
# Q6

age = 22

if age >= 18:
    if age >= 21:
        print("Can enter VIP section")
    else:
        print("Adult")
else:
    print("Minor")
# Out:
# Can enter VIP section

# %%
# Q7

username = "admin"
password = "1234"

if username == "admin":
    if password == "1234":
        print("Login Successful")
    else:
        print("Wrong Password")
else:
    print("Invalid Username")
# Out:
# Login Successful

# %%
# Q8

num = -5

if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("Zero")
# Out:
# Negative

# %%
# Q9

age = 17

result = "Adult" if age >= 18 else "Minor"
print(result)
# Out:
# Minor

# %%
# Q10

balance = 5000
withdraw = 2000

if withdraw <= balance:
    balance -= withdraw
    print("Withdrawal successful")
    print("Remaining balance:", balance)
else:
    print("Insufficient balance")
# Out:
# Withdrawal successful
# Remaining balance: 3000
