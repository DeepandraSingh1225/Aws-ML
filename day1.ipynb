# %% [markdown]
# <a href="https://colab.research.google.com/github/DeepandraSingh1225/Aws-ML/blob/main/day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# if both values are same then the addresss or id of the variables is same


a = 'anshu'
print(a)
print(id(a))


b = 'anshu'
print(b)
print(id(b))


print(id(a))
print(id(b))
# Out:
# anshu
# 132048757139296
# anshu
# 132048757139296
# 132048757139296
# 132048757139296
