# %% [markdown]
# <a href="https://colab.research.google.com/github/DeepandraSingh1225/Aws-ML/blob/main/day8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive


data = open("hello.txt" , "r")
data.read()
# Out:
# 'Hllo file handling '

# %%
d = open('hello.txt' , 'w')
print(d.write('hello world'))
d = open('hello.txt' , 'r')
d.read()
# Out:
# 11
# 'hello world'

# %% [markdown]
# ## Numpy

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

l = [10,20,30,40]
l*2
# Out:
# [10, 20, 30, 40, 10, 20, 30, 40]

# %%
arr = np.array(l)
arr*2
# Out:
# array([20, 40, 60, 80])

# %%
l = [10,20,30,40]
print(l)
print(type(l))


arr = np.array(l)
print(arr)
print(type(arr))
# Out:
# [10, 20, 30, 40]
# <class 'list'>
# [10 20 30 40]
# <class 'numpy.ndarray'>

# %%
arr = np.array(l)
print(arr+2)
# Out:
# [12 22 32 42]

# %%
# python range

for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# numpy arange

for i in np.arange(0,5,2):          # (start , stop , step)
  print(i)
# Out:
# 0
# 2
# 4

# %%
arr = np.arange(5)
print(arr)
# Out:
# [0 1 2 3 4]

# %% [markdown]
# - #### 2 dimensional

# %%
arr = np.array([[l] , [l]] )
arr
# Out:
# array([[[10, 20, 30, 40]],
#
#        [[10, 20, 30, 40]]])

# %% [markdown]
# #### 3 dimensional

# %%
arr = np.array([[[l] , [l] ] , [[l] , [l] ]] )
arr
# Out:
# array([[[[10, 20, 30, 40]],
#
#         [[10, 20, 30, 40]]],
#
#
#        [[[10, 20, 30, 40]],
#
#         [[10, 20, 30, 40]]]])
