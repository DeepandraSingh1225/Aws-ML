# %% [markdown]
# <a href="https://colab.research.google.com/github/DeepandraSingh1225/Aws-ML/blob/main/day8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive


data = open("/content/drive/MyDrive/hello.txt" , "r")
data.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_4176/1647766343.py in <cell line: 0>()
#       2
#       3
# ----> 4 data = open("/content/drive/MyDrive/hello.txt" , "r")
#       5 data.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/hello.txt'

# %%
# write and read
data2 = open("/content/drive/MyDrive/hello.txt","w")
data2.write("we are indians")

data2 = open("/content/drive/MyDrive/hello.txt","r")
data2.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_4176/3878291500.py in <cell line: 0>()
#       1 # write and read
# ----> 2 data2 = open("/content/drive/MyDrive/hello.txt","w")
#       3 data2.write("we are indians")
#       4
#       5 data2 = open("/content/drive/MyDrive/hello.txt","r")
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/hello.txt'
